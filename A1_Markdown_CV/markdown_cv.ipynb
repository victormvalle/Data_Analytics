# %% [markdown]
# # <center></center>
# # <center> Victor Valle </center>
# ######<center> Email: [victormvalle1@protonmail.com](victormvalle1@protonmail.com)
# ######<center> Linkedin: [linkedin.com/in/victormvalle1](https://www.linkedin.com/in/victormvalle1)
# ######<center> GitHub: [github.com/victormvalle](https://github.com/victormvalle)
#
#
# <br>
#
# ## Summary
# ---
#
# - **Analytical Thinker** – Experienced in econometric modeling, statistical analysis (Python, Stata), and predictive analytics, demonstrated through research projects, statistical modeling, and teaching in Business Analytics courses
# - **Strong Communicator & Collaborator** – Proven background in research, teaching, and business operations, adept at translating complex data into actionable insights while working cross-functionally with students and faculty
# - **Data-Driven Problem Solver** – Expertise in SQL, Python, and Tableau to extract insights, optimize databases, and develop interactive visualizations for informed decision-making
#
# <br>
#
# ## Education
# ---
# **Southern Utah University** -- March 2026 <br>
# *Cedar City, UT*<br>
# Master in Business Administration
#
# <br>
#
# **Southern Utah University** -- March 2026 <br>
# *Cedar City, UT*<br>
# M.S. Business Analytics
#
# <br>
#
# **Southern Utah University** -- August 2024 <br>
# *Cedar City, UT*<br>
# B.S. ECONOMICS
# - Business Analytics Emphasis
# - Studying Econometrics using STATA, Data Analytics using Python, and Database Management using MySQL
#
# <br>
#
# ## Work Experience
# ---
# **TEACHING ASSISTANT** Sept 2023-Current <br>
# *Southern Utah University (Suu)*
#
# - Assist students in ANLY 2500 (Introduction to Business Analytics) and ANLY 3250 (Data Management & Organization) with **Python, SQL, and Tableau**
# - Conduct weekly office hours, providing one-on-one support for data processing, visualization, and database management
# - Grade assignments and projects, providing feedback on Python scripting, SQL queries, and data visualization best practices
#
#
# <br>
#
# **RESEARCH ASSISTANT** Sept 2024-Current <br>
# *SUU*
#
# - Conduct economic research on how marijuana legalization impacts job outcomes across U.S. states, focusing on labor force participation, employment rates, and wage trends
# - Utilize **R** and **Python** to perform data wrangling, visualization, and statistical modeling, including regression analysis and hypothesis testing
#
#
# <br>
#
# **BUSINESS OPERATIONS SPECIALIST** May 2018-Current <br>
# *Pronto Pallets*
# - Design, develop, and maintain the company’s [website](https://prontopallets.com/)
# - Oversee financial organization by digitizing and managing receipts in QuickBooks, assisting in tax preparation and financial reporting
#
#
# <br>
#
# **COMMUNITY ANALYST** Oct 2023-Mar 2024 <br>
# *Kinect Capital*
#
# - Tracking and analyzing data related to Kinect’s programs
# - Collaborate with the team to design and administer surveys to gather valuable insights
# - Creating reports and presentations summarizing research findings for internal and external stakeholders
#
# <br>
#
# **VIP SUPPORT TECH/SYSTEM ADMIN** Oct 2016-Apr 2018 <br>
# *eBay*
# - Administered Executive Assistants via emails, chat, and phone calls on technical issues
# - Aided all eBay members on Outlook issues: delegating accounts, creating aliases, O365 issues
# - Helped in creating Knowledge Base Articles for others to use
#
# <br>
#
# **INSTRUCTOR** Oct 2016 - Apr 2018 <br>
# *Salt Lake Community College (SLCC)*
# - Schedule instructor's courses and copy their material
# - Communicate with students through Outlook, phone, face-to-face or mail
# - Maintaining student's records update through MS Access
#
# <br>
#
# **DATA CLERK** Mar 2014-Aug 2016 <br>
# *SLCC Computer Workshops*
# - Schedule instructor's courses and copy their material
# - Communicate with students through Outlook, phone, face-to-face or mail
# - Maintaining student's records update through MS Access
#
# <br>
#
# **SECRETARY** Sept 2013-Mar 2014 <br>
# *SLCC Dental Hygiene Clinic*
# - Helped Spanish-speaking patients with instructions during and after cleaning
# - Maintained the front office in check: receiving messages, sending/receiving mail, sending faxes, managing files
#
# <br>
#
# **ADMINISTRATIVE ASSISTANT** Sept 2012-Dec 2013\
# *S and V Trucking*
# - Schedule instructor's courses and copy their material
# - Communicate with students through Outlook, phone, face-to-face or mail
# - Maintaining student's records update through MS Access
#
# <br>
#
# **GROUP LEADER** Aug 2010-Sept 2012 <br>
# *Salt Lake City District*
# - In charge of about 15 elementary students in the After-School Program
# - Taught students variety skills: visual arts, physical education, music, etc.
#
# <br>
#
# ## Skills
# ---
# **MS Office:** Excel, Word, Powerpoint, Access <br>
# **Languages:** Spanish (fluent), German (beginning) <br>
# **IT Skills**  A+, Network+ <br>
# **Programming Skills:**  Bash/Shell, Java, Linux, HTML5/CSS/JS
